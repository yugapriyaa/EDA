# %% [markdown]
# # Python Foundations Project: Austo
#
# **Marks: 60**

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context
#
# In the 21st century, cars are an important mode of transportation that provides us the opportunity for personal control and autonomy. In day-to-day life, people use cars for commuting to work, shopping, visiting family and friends, etc. Research shows that more than 76% of people prevent themselves from traveling somewhere if they don't have a car. Most people tend to buy different types of cars based on their day-to-day necessities and preferences. So, it is essential for automobile companies to analyze the preference of their customers before launching a car model into the market. Austo, a UK-based automobile company aspires to grow its business into the US market after successfully establishing its footprints in the European market.
#
# In order to be familiar with the types of cars preferred by the customers and factors influencing the car purchase behavior in the US market, Austo has contracted a consulting firm. Based on various market surveys, the consulting firm has created a dataset of 3 major types of cars that are extensively used across the US market. They have collected various details of the car owners which can be analyzed to understand the automobile market of the US.
#
# ### Objective
#
# Austo's management team wants to understand the demand of the buyers and trends in the US market. They want to build customer profiles based on the analysis to identify new purchase opportunities so that they can manipulate the business strategy and production to meet certain demand levels. Further, the analysis will be a good way for management to understand the dynamics of a new market. Suppose you are a Data Scientist working at the consulting firm that has been contracted by Austo. You are given the task to create buyer's profiles for different types of cars with the available data as well as a set of recommendations for Austo. Perform the data analysis to generate useful insights that will help the automobile company to grow its business.
#
# ### Data Description
#
# austo_automobile.csv: The dataset contains buyer's data corresponding to different types of products(cars).
#
# ### Data Dictionary
#
# * Age: Age of the customer
# * Gender: Gender of the customer
# * Profession: Indicates whether the customer is a salaried or business person
# * Marital_status: Marital status of the customer
# * Education: Refers to the highest level of education completed by the customer
# * No_of_dependents: Number of dependents(partner/children/spouse) of the customer
# * Personal_loan: Indicates whether the customer availed a personal loan or not
# * House_loan: Indicates whether the customer availed house loan or not
# * Partner_working: Indicates whether the customer's partner is working or not
# * Salary: Annual Salary of the customer
# * Partner_salary: Annual Salary of the customer's partner
# * Total_salary: Annual household income (Salary + Partner_salary) of the customer's family
# * Price: Price of the car
# * Make: Car type (Hatchback/Sedan/SUV)

# %% [markdown]
# ## Importing necessary libraries

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#Access to Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Importing the dataset

# %%
# read the data
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Austo_Project/austo_automobile.csv')
# returns the first 5 rows
df.head()
# Out:
#    Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 0   24   Male   Salaried        Married  Post Graduate                 4
# 1   28   Male   Salaried        Married  Post Graduate                 3
# 2   23   Male   Salaried        Married       Graduate                 4
# 3   26   Male   Business        Married  Post Graduate                 4
# 4   28   Male   Business        Married  Post Graduate                 4
#
#   Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 0            No        Yes             Yes   52000           25000
# 1            No        Yes              No   68000               0
# 2           Yes        Yes              No   31000               0
# 3           Yes        Yes             Yes   66000           35000
# 4           Yes         No              No   64000               0
#
#    Total_salary  Price       Make
# 0         77000  18000  Hatchback
# 1         68000  18000  Hatchback
# ...

# %%
df.tail()
# Out:
#       Age Gender Profession Marital_status      Education  No_of_Dependents  \
# 1576   28   Male   Salaried        Married  Post Graduate                 2
# 1577   23   Male   Salaried         Single       Graduate                 2
# 1578   23   Male   Business        Married       Graduate                 4
# 1579   25   Male   Business        Married  Post Graduate                 3
# 1580   28   Male   Salaried        Married       Graduate                 4
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# 1576           Yes         No              No   72000               0
# 1577           Yes        Yes              No   37000               0
# 1578           Yes        Yes             Yes   38000           28000
# 1579           Yes        Yes             Yes   58000           40000
# 1580            No        Yes             Yes   54000           40000
#
#       Total_salary  Price       Make
# 1576         72000  33000  Hatchback
# ...

# %% [markdown]
# ## Data Overview

# %% [markdown]
# #### Question 1: How many rows and columns are present in the data? [0.5 mark]

# %%
# Shape command to find the rows and columns
df.shape
# Out:
# (1581, 14)

# %% [markdown]
# #### Observations:
#
#
# 1.   Number of rows = 1581
# 2.   Number of columns = 14

# %% [markdown]
# #### Question 2: What are the datatypes of the different columns in the dataset? [0.5 mark]

# %%
# Info command to find the Datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   int64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: int64(6), object(8)
# memory usage: 173.0+ KB

# %% [markdown]
# #### Observations:
#
# *   Total number of columns are 14
# *   In which, 6 are int64 type and 8 are of object type
# *   Data type of each coulmn is appropriate, needs no casting
# *   All coulmns have meaningful values, no null values are present

# %% [markdown]
# #### Question 3: Check the statistical summary of the data. What is the minimu, avergae, and maximum Price of the cars? [2 marks]

# %%
# Describe to get the statistical data
# Transpose for better view
df.describe().T
# Out:
#                    count          mean           std      min      25%  \
# Age               1581.0     32.211259      9.125477     22.0     25.0
# No_of_Dependents  1581.0      2.457938      0.943483      0.0      2.0
# Salary            1581.0  59732.447818  14278.642665  30000.0  51000.0
# Partner_salary    1581.0  19720.430108  19480.214404      0.0      0.0
# Total_salary      1581.0  79452.877925  24855.936043  30000.0  61000.0
# Price             1581.0  35597.722960  13633.636545  18000.0  25000.0
#
#                       50%      75%       max
# Age                  29.0     38.0      60.0
# No_of_Dependents      2.0      3.0       4.0
# Salary            59000.0  71000.0   90000.0
# Partner_salary    25000.0  38000.0   80000.0
# Total_salary      78000.0  96000.0  158000.0
# Price             31000.0  47000.0   70000.0

# %% [markdown]
# #### Observations:
#
# *   Minimum price of car = $18000.0
#
# *   Average price of car = $35597.72
#
# *   Maximunm price of car = $70000.0

# %% [markdown]
# #### Question 4: Are there any missing values in the data? If yes, treat them using an appropriate method.  [1 Mark]

# %%
# Find missing values for Age
df['Age'].unique()
# Out:
# array([24, 28, 23, 26, 36, 27, 46, 44, 35, 29, 32, 30, 39, 22, 40, 47, 53,
#        58, 42, 25, 56, 38, 43, 37, 31, 33, 60, 34, 41, 55, 51, 54, 52, 45,
#        59, 57, 50, 48, 49])

# %%
# Find missing values for Gender
df['Gender'].value_counts()
# Out:
# Male      1252
# Female     329
# Name: Gender, dtype: int64

# %%
# Find missing values for Profession
df['Profession'].value_counts()
# Out:
# Salaried    896
# Business    685
# Name: Profession, dtype: int64

# %%
# Find missing values for Marital_status
df['Marital_status'].value_counts()
# Out:
# Married    1443
# Single      138
# Name: Marital_status, dtype: int64

# %%
# Find missing values for Education
df['Education'].value_counts()
# Out:
# Post Graduate    985
# Graduate         596
# Name: Education, dtype: int64

# %%
# Find missing values for No_of_Dependents
df['No_of_Dependents'].value_counts()
# Out:
# 3    557
# 2    557
# 1    229
# 4    218
# 0     20
# Name: No_of_Dependents, dtype: int64

# %%
# Find missing values for Personal_loan
df['Personal_loan'].value_counts()
# Out:
# Yes    792
# No     789
# Name: Personal_loan, dtype: int64

# %%
# Find missing values for House_loan
df['House_loan'].value_counts()
# Out:
# No     1054
# Yes     527
# Name: House_loan, dtype: int64

# %%
# Find missing values for Partner_working
df['Partner_working'].value_counts()
# Out:
# Yes    868
# No     713
# Name: Partner_working, dtype: int64

# %%
# Find missing values for Salary
df['Salary'].unique()
# Out:
# array([52000, 68000, 31000, 66000, 64000, 48000, 76000, 80000, 30000,
#        70000, 67000, 84000, 61000, 56000, 58000, 65000, 72000, 53000,
#        59000, 87000, 42000, 39000, 60000, 54000, 57000, 36000, 69000,
#        78000, 51000, 49000, 71000, 37000, 63000, 43000, 74000, 75000,
#        73000, 62000, 32000, 35000, 50000, 79000, 77000, 55000, 90000,
#        33000, 44000, 47000, 40000, 34000, 85000, 82000, 86000, 89000,
#        38000, 46000, 81000, 41000, 45000, 83000, 88000])

# %%
# Find missing values for Partner_salary
df['Partner_salary'].unique()
# Out:
# array([25000,     0, 35000, 40000, 22000, 50000, 26000, 27000, 30000,
#        45000, 24000, 28000, 60000, 23000, 29000, 38000, 70000, 32000,
#        80000])

# %%
# Find missing values for Total_salary
df['Total_salary'].unique()
# Out:
# array([ 77000,  68000,  31000, 101000,  64000,  66000,  88000, 111000,
#         80000,  30000,  70000,  67000,  52000,  84000,  96000,  76000,
#         91000,  58000,  89000, 100000, 122000,  53000,  59000,  87000,
#        130000,  74000,  60000, 113000,  97000,  63000, 109000, 118000,
#         51000,  75000, 104000,  37000, 103000,  57000,  85000,  65000,
#        124000, 105000,  73000,  62000,  35000,  39000,  86000,  99000,
#         56000,  79000, 102000,  92000,  36000,  32000,  90000,  44000,
#         71000,  55000,  40000,  78000,  69000,  94000, 108000, 120000,
#        106000,  49000,  83000,  34000, 119000,  82000, 137000, 126000,
#        139000,  72000,  38000,  50000,  81000,  98000, 115000, 112000,
#        116000,  42000, 128000,  93000,  95000,  61000,  41000, 129000,
#        132000,  54000, 142000, 117000, 110000, 145000, 149000, 131000,
#         33000, 148000, 121000, 138000, 107000, 144000, 114000, 134000,
# ...

# %%
# Find missing values for Price
df['Price'].unique()
# Out:
# array([18000, 49000, 31000, 50000, 19000, 32000, 51000, 20000, 33000,
#        52000, 34000, 53000, 21000, 54000, 35000, 55000, 22000, 36000,
#        56000, 23000, 57000, 37000, 38000, 24000, 39000, 58000, 40000,
#        25000, 41000, 59000, 42000, 26000, 60000, 43000, 27000, 61000,
#        44000, 45000, 28000, 62000, 46000, 47000, 63000, 29000, 48000,
#        64000, 30000, 65000, 66000, 67000, 68000, 69000, 70000])

# %%
# Find missing values for Make
df['Make'].value_counts()
# Out:
# Hatchback    884
# Sedan        460
# SUV          237
# Name: Make, dtype: int64

# %% [markdown]
# #### Observations:
#
# *   There is no missing data
# *   All columns have values in all cells

# %% [markdown]
# #### Question 5: How many cars are there of type SUV? [1 mark]

# %%
# Find total cars in SUV
df['Make'].value_counts()
# Out:
# Hatchback    884
# Sedan        460
# SUV          237
# Name: Make, dtype: int64

# %% [markdown]
# #### Observations:
#
# *   SUV cars count = 237

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### **Question 6:** Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.) [10 marks]

# %%
#Numerical data - Age
sns.histplot(data=df,x='Age');

# %% [markdown]
# #### Observations:
# **Age:**
# *   Consumers age range from 23 to 60
# *   Consumers of age 23 to 30 counts to 200-300, grouping to majority of car buyers
# *   Consumers of age 31 to 45 fall between 50 to 100 count
# *   Consumers of age 46 to 60 counts to below 50

# %%
#Categorical data - Gender
sns.countplot(data=df,x='Gender');

# %% [markdown]
# #### Observations:
# **Gender:**
# *   Clearly Male buyers are more, counting above 1200
# *   Female consumers are comparitively less counting to approx. 350

# %%
#Categorical data - Profession
sns.countplot(data=df,x='Profession');

# %% [markdown]
# #### Observations:
# **Profession:**
#
#
# *   Around 900 people are salaried employees that buy a car
# *   Whereas, Business owners are around 700 likely to buy a car
# *   Clearly, Salaried employees forms the bigger group in buying cars

# %%
#Categorical data - Marital_status
sns.countplot(data=df,x='Marital_status');

# %% [markdown]
# #### Observations:
# **Marital_status**
#
# *   Marital status clearly indicates that married people are most interested in buying cars, counting more than 1400
# *   Singles are less likely to buy cars, falls less than 200

# %%
#Categorical data - Education
sns.countplot(data=df,x='Education');

# %% [markdown]
# #### Observations:
#
# **Education**
# *   Post graduates are buying cars more than Graduate group, counting just below 1000
# *   Graduates competes with PG group and closing to 600 count

# %%
#Numerical data - No_of_Dependents
sns.histplot(data=df,x='No_of_Dependents');

# %% [markdown]
# #### Observations:
# **No_of_Dependents:**
#
# *   Interestingly, when the dependent count is max i.e., above 3 - the consumer's interest t0 buy a car is reduced
# *   When the dependent count is 2 or 3, intention of buying car increses. This group clearly marks majority above 500

# %%
#Categorical data - Personal_loan
sns.countplot(data=df,x='Personal_loan');

# %% [markdown]
# #### Observations:
#
#
#
#
#
#
#
#
#
#
#
# **Personal_loan:**
# *   Status of personal loan - Weather consumer has a personal or no does NOT affect the potential of buying a car
# *   So both the columns are in equal count

# %%
#Categorical data - House_loan
sns.countplot(data=df,x='House_loan');

# %% [markdown]
# #### Observations:
# **House loan:**
#
# *   Distinctly, People with no housing loan tends to buy car, counting above 1000
# *   People with housing loan are less likely to buy a car, counting to approx. 500

# %%
#Categorical data - Partner_working
sns.countplot(data=df,x='Partner_working');

# %% [markdown]
# #### Observations:
# **Partner working status:**
#
# *   Partner working status slightly influence the car buying potential.
# *   People with working partners forms a slight majority, counting above 900
# *   Whereas people with single salary counts to 700, not a major difference from the above

# %%
#Numerical data - Salary
sns.histplot(data=df,x='Salary');

# %% [markdown]
# #### Observations:
# **Salary:**
# *   People who gets $50000 - $65000 are the target group, counts more than 150
# *   There is also a car buying hike in salary range $70000 - $75000
# *   Overall, the car buying tendancy decreases with the increase in salary

# %%
#Numerical data - Partner_salary
sns.histplot(data=df,x='Partner_salary');

# %% [markdown]
# #### Observations:
# **Partner Salary:**
#
# *   With clarity, car buying potential decreases with increase in Partner's salary. Probably able to afford luxury cars :-)
# *   Target group is partner salary ranging upto $5000
# *   Partner salary ranging from 25 to 32k and 38 to 42k also makes a good group in buying cars

# %%
#Numerical data - Total_salary
sns.histplot(data=df,x='Total_salary');

# %% [markdown]
# #### Observations:
# **Total Salary:**
#
# *   This graph marks a bell curve, with an sharp hike in total salary range 52 to 60k approx
# *   Buying potential again reaches maximum when the total salary is between 78 to 82k approx
# *   Notably, when the total salary increases Car buying tendancy decreases. Probably preferring other makes.

# %%
#Numerical data - Price
sns.histplot(data=df,x='Price');

# %% [markdown]
# #### Observations:
# **Price:**
# *   Clearly, with Price increase buying potential drops down
# *   If we produce cars in the range of 22 to 35k, we can easily target the buyers

# %%
#Categorical data - Make
sns.countplot(data=df,x='Make');

# %% [markdown]
# #### Observations:
# **Make:**
# *   Hatchback is the hot selling car followed by Sedan
# *   SUV is the least preferred car, counting to just above 200

# %% [markdown]
# #### Question 7: How many cars are of make Hatchback and priced above 25000. State your observations? [2 marks]

# %%
# groupby make and price and store in a data frame
df_hb = df[['Price','Make']]
#df_hb
df_pricelessthan25k = np.where((df_hb['Make']=='Hatchback') & (df_hb['Price']>25000))
display(df_hb.loc[df_pricelessthan25k])
# Out:
#       Price       Make
# 773   26000  Hatchback
# 774   26000  Hatchback
# 775   26000  Hatchback
# 778   26000  Hatchback
# 779   26000  Hatchback
# ...     ...        ...
# 1576  33000  Hatchback
# 1577  33000  Hatchback
# 1578  33000  Hatchback
# 1579  33000  Hatchback
# 1580  33000  Hatchback
#
# [444 rows x 2 columns]

# %% [markdown]
# #### Observations:
#
#
# *   There are 444 hatchbacks priced above $25000, out of 1581 total cars

# %% [markdown]
# #### Question 8: How many owners have bought cars that were priced higher than their salary. How many of them have taken personal loan? [3 marks]

# %%
# Write the code here
#df_new2 = np.where((df['Price']>df['Salary']) & (df['Personal_loan']=='Yes'))
#display(df.loc[df_new2])
#display(df.loc[df_new2].value_counts().sum())


df_new2 = np.where((df['Price']>df['Salary']))
display(df.loc[df_new2])
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 117    37    Male   Salaried        Married       Graduate                 3
# 128    41  Female   Salaried        Married       Graduate                 2
# 170    38  Female   Salaried        Married       Graduate                 3
# 212    45    Male   Salaried        Married       Graduate                 3
# 306    35    Male   Salaried        Married       Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1538   35    Male   Salaried        Married       Graduate                 4
# 1540   36    Male   Salaried        Married  Post Graduate                 4
# 1552   31    Male   Business        Married       Graduate                 2
# 1568   24    Male   Salaried        Married       Graduate                 3
# 1573   35    Male   Business        Married  Post Graduate                 4
#
# ...

# %%
df_new2 = np.where((df['Price']>df['Salary']) & (df['Personal_loan']=='Yes'))
display(df.loc[df_new2])
display(df.loc[df_new2].value_counts().sum())
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 128    41  Female   Salaried        Married       Graduate                 2
# 170    38  Female   Salaried        Married       Graduate                 3
# 394    38    Male   Business        Married       Graduate                 2
# 450    39    Male   Salaried        Married       Graduate                 3
# 546    33  Female   Salaried        Married       Graduate                 2
# 582    35  Female   Salaried        Married       Graduate                 2
# 698    30  Female   Business        Married       Graduate                 2
# 743    44  Female   Salaried        Married       Graduate                 3
# 790    42    Male   Business        Married       Graduate                 3
# 806    33  Female   Salaried        Married       Graduate                 2
# 859    30    Male   Business        Married       Graduate                 2
# ...

# %% [markdown]
# #### Observations:
# *   96 owners have bought cars that were priced higher than their salary.
# *   44 out of 96 has taken personal loan

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### Question 9: Perform a multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables) [15 marks]

# %%
# Seperate numerical columns
numeric_data = df.select_dtypes(include=[np.number])
#numeric_data

# Display relationship between all variables
corr = numeric_data.corr()
corr.style.background_gradient(cmap ='Pastel2')
# Out:
# <style type="text/css">
# #T_635b3_row0_col0, #T_635b3_row1_col1, #T_635b3_row2_col2, #T_635b3_row3_col3, #T_635b3_row4_col4, #T_635b3_row5_col5 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_635b3_row0_col1, #T_635b3_row0_col3, #T_635b3_row1_col0, #T_635b3_row1_col2, #T_635b3_row1_col3, #T_635b3_row1_col4, #T_635b3_row1_col5, #T_635b3_row2_col1, #T_635b3_row2_col3, #T_635b3_row3_col2, #T_635b3_row5_col1, #T_635b3_row5_col3 {
#   background-color: #b3e2cd;
#   color: #000000;
# }
# #T_635b3_row0_col2, #T_635b3_row2_col4, #T_635b3_row4_col0 {
#   background-color: #e6f5c9;
#   color: #000000;
# }
# #T_635b3_row0_col4, #T_635b3_row2_col5, #T_635b3_row4_col5, #T_635b3_row5_col2 {
#   background-color: #f4cae4;
#   color: #000000;
# }
# #T_635b3_row0_col5, #T_635b3_row3_col4, #T_635b3_row4_col3, #T_635b3_row5_col0 {
#   background-color: #f1e2cc;
#   color: #000000;
# }
# #T_635b3_row2_col0, #T_635b3_row4_col2 {
#   background-color: #fff2ae;
#   color: #000000;
# }
# ...

# %%
#Price vs Salary
sns.lineplot(y='Price',x='Salary',data=df);

# %% [markdown]
# #### Observations:
#
#
# *   Clearly, when salary increases,potential of buying expensive cars increases
# *   Salary and Price are correlated positive

# %%
#Price vs Total_salary
sns.lineplot(x='Price',y='Total_salary',data=df);

# %% [markdown]
# #### Observations:
#
#
# *   Price and Total salary are postive correlated
# *   When Total salary increases, affordability increases
#
# *   Affording expensive cars increases with partner working
# *   Peak shows above 50k. whereas when Partner not working, the peak is below 50k

# %%
# Salary vs make
sns.boxplot(x='Salary',y='Make',data=df);

# %% [markdown]
# #### Observations:
#
#
# *   Consumers with Higher income(68-82k) prefers SUV
# *   Consumers with moderate income(55-72k) opts for Sedan
# *   Consumers with comparitively lesser income(45-65k) likes to buy Hatchback

# %%
# Total salary vs make
sns.boxplot(x='Total_salary',y='Make',data=df);

# %% [markdown]
# #### Observations:
#
#
#
# 1.   Follows the same trend as above.
# *   Consumers with Higher income(75-130k) prefers SUV
# *   Consumers with moderate income(60-100k) opts for Sedan
# *   Consumers with comparitively lesser income(58-85k) likes to buy Hatchback

# %%
#Age vs Price
sns.lmplot(y='Price',x='Age',data=df,line_kws={'color': 'red'});

# %% [markdown]
# #### Observations:
#
#
# *   As Age increases, affordability to pricey cars increases

# %%
#Age vs Make
sns.boxplot(x='Age',y='Make',data=df);

# %% [markdown]
# #### Observations:
#
# *   Younger consumers(20-30) tend to buy Hatchback
# *   Consumer age ranging from 33 - 42 likes to buy Sedan
# *   Senior consumers (41-55) prefers SUV

# %%
#Dependents vs Make
sns.boxplot(x='No_of_Dependents',y='Make',data=df);

# %% [markdown]
# #### Observations:
#
#
# *   When dependants are less, 1 or 2 then consumers prefer Sedan
# *   When dependants are more than 2, consumers opt for Hatchback and SUV

# %%
#Gender vs Price
sns.boxplot(x='Price',y='Gender',data=df);

# %% [markdown]
# #### Observations:
#
#
# *   Males prefer less expensive cars, with notable exeptions
# *   Females opt for relatively higher priced cars

# %%
#Gender vs Make
sns.histplot(binwidth=0.5, x="Make", hue="Gender", data=df, stat="count", multiple="stack");

# %% [markdown]
# #### Observations:
#
# *   Males prefer Hatchback, Sedan and SUV respectively
# *   Females prefers Sedan, Suv and Hatchback respectively

# %%
#Houseloan vs Price
sns.swarmplot(y='Price',x='House_loan',data=df);

# %% [markdown]
# #### Observations:
#
# *   Consumers with House loan forms smaller group and buys less expensive cars. Max price is 55k
# *   Consumers with no House loan is more in count and can afford expensive cars. Price max being 70k

# %% [markdown]
# #### Question 10:For customers who have 3 or fewer dependents, how does the average car price vary by profession ? [2 marks]

# %%
# Write the code here
df_new3 = np.where((df['No_of_Dependents']<=3))
display(df.loc[df_new3])
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 1      28    Male   Salaried        Married  Post Graduate                 3
# 5      36    Male   Salaried        Married  Post Graduate                 3
# 7      27    Male   Salaried        Married  Post Graduate                 3
# 8      46  Female   Salaried         Single  Post Graduate                 0
# 9      24    Male   Salaried         Single       Graduate                 2
# ...   ...     ...        ...            ...            ...               ...
# 1570   30  Female   Salaried        Married  Post Graduate                 2
# 1574   22    Male   Business        Married       Graduate                 3
# 1576   28    Male   Salaried        Married  Post Graduate                 2
# 1577   23    Male   Salaried         Single       Graduate                 2
# 1579   25    Male   Business        Married  Post Graduate                 3
#
# ...

# %% [markdown]
# #### Observations:

# %% [markdown]
# #### Question 11: For customers who have availed a home loan and a personal loan, how does the price vary by profession? [3 marks]

# %%
# Write the code here

#df_pvar = np.where((df['Personal_loan']=='Yes') & (df['House_loan']=='Yes'))
#display(df.loc[df_pvar])
#print(type(df_pvar))

#df_newdf = pd.DataFrame(df_pvar)
#print(type(df_newdf))

# Add a new column named 'Both-Loans'
#df['Price'] = [1500 if x =='Music' else 800 for x in df['Event']]
#df['Both-Loans'] = ['Yes' if (x=='Yes' & y=='Yes') else 'NO' for x in df['Personal_loan'] y in df['House_loan']]

sns.lineplot(x='Price',y='Profession',hue='Personal_loan', data=df,ci=None)
# Out:
# <Axes: xlabel='Price', ylabel='Profession'>

# %%
sns.lineplot(x='Price',y='Profession',hue='House_loan', data=df,ci=None)
# Out:
# <Axes: xlabel='Price', ylabel='Profession'>

# %% [markdown]
# #### Observations:

# %% [markdown]
# ## Conclusion and Recommendations

# %% [markdown]
# #### **Question 12:** Write the conclusions and business recommendations derived from the analysis. (6 marks)

# %% [markdown]
# **Business Recommendations:**
#
# **Age:**
# *   Majority car buyers are in age group 23 - 30
# *   Total consumers age range from 23 to 60
# *   Younger consumers(20-30) tend to buy Hatchback
# *   Consumer age ranging from 33 - 42 likes to buy Sedan
# *  Senior consumers (41-55) prefers SUV
#
# **Price:**
#
# *   If we produce cars in the range of 22 to 35k, we can easily target the buyers
# *   Clearly, with Price increase buying potential drops down
#
# **Make:**
#
#
# *   Hatchback is the hot selling car followed by Sedan, SUV is the least preferred car
# *   Consumers with Higher income(68-82k) prefers SUV
# *   Consumers with moderate income(55-72k) opts for Sedan
# *   Consumers with comparitively lesser income(45-65k) likes to buy Hatchback
#
# **Gender:**
#
# *   Clearly Male buyers are more,Female consumers are comparitively less
# *   Males prefer less expensive cars, with notable exeptions
# *   Males prefer Hatchback, Sedan and SUV respectively
# *   Females opt for relatively higher priced cars
# *  Females prefers Sedan, Suv and Hatchback respectively
#
# **Salary:**
#
# *   Salaried employees forms the bigger group in buying cars
# *   People who gets salary between $50000 − $65000 are the target group
# *   Partner salary ranging from 25 to 32k and 38 to 42k also makes a good group in buying cars
# *   Buying potential again reaches maximum when the total salary is between 78 to 82k approx
# *   Car buying potential decreases with increase in Partner's salary - may be looking for luxury options
# *   Overall, the car buying tendancy decreases with the increase in salary - may be looking for luxury options
#
# **Loans:**
#
# *   People with no housing loan are more likely to buy a car
# *  Personal loan does NOT affect the potential of buying a car
# *   Consumers with House loan forms smaller group and buys less expensive cars. Max price is 55k
# *   Consumers with no House loan is more in count and can afford expensive cars, Price max being 70k
#
# **Marital status & Dependents:**
#
#
# *   Marital status clearly indicates that married people are most interested in buying cars
# *   When the dependent count is 2 or 3, intention of buying car increases
# *   When dependants are less, 1 or 2 then consumers prefer Sedan
# *   When dependants are more than 2, consumers opt for Hatchback and SUV
#
#
# **Miscellaneous:**
#
# *   Post graduates are buying cars more than Graduate group
# *   As Age increases, affordability to pricey cars increases
#
#
#
#         **  Welcome to the United States! I wish AUSTO all the best!!!**

# %% [markdown]
# ___
